# %%
from ospo_stats.db import export

# %%
df = export("repo")
df.head()

# %%
df.to_parquet("../data/repo.parquet")

# %%
df = export("commit_history")
df.to_parquet("../data/commit_history.parquet")
df.head()
# Out:
# Fetching rows 0 to 500
# Fetching rows 500 to 1000
# Fetching rows 1000 to 1500
# Fetching rows 1500 to 2000
# Fetching rows 2000 to 2500
# Fetching rows 2500 to 3000
# Fetching rows 3000 to 3500
# Fetching rows 3500 to 4000
# Fetching rows 4000 to 4500
# Fetching rows 4500 to 5000
# Fetching rows 5000 to 5500
# Fetching rows 5500 to 6000
# Fetching rows 6000 to 6500
# Fetching rows 6500 to 7000
# Fetching rows 7000 to 7500
# Fetching rows 7500 to 8000
# Fetching rows 8000 to 8500
# Fetching rows 8500 to 9000
# Fetching rows 9000 to 9500
# Fetching rows 9500 to 10000
# Fetching rows 10000 to 10500
# Fetching rows 10500 to 11000
# Fetching rows 11000 to 11500
# Fetching rows 11500 to 12000
# Fetching rows 12000 to 12500
# Fetching rows 12500 to 13000
# Fetching rows 13000 to 13500
# Fetching rows 13500 to 14000
# Fetching rows 14000 to 14500
# Fetching rows 14500 to 15000
# Fetching rows 15000 to 15500
# Fetching rows 15500 to 16000
# Fetching rows 16000 to 16500
# ...

# %%
df = export("stargazer_history")
df.to_parquet("../data/stargazer_history.parquet")
df.head()
# Out:
# Fetching rows 0 to 500
# Fetching rows 500 to 1000
# Fetching rows 1000 to 1500
# Fetching rows 1500 to 2000
# Fetching rows 2000 to 2500
# Fetching rows 2500 to 3000
# Fetching rows 3000 to 3500
# Fetching rows 3500 to 4000
# Fetching rows 4000 to 4500
# Fetching rows 4500 to 5000
# Fetching rows 5000 to 5500
# Fetching rows 5500 to 6000
# Fetching rows 6000 to 6500
# Fetching rows 6500 to 7000
#                                                   id  \
# 0  https://github.com/0205Rahul/Breast-Cancer-pre...
# 1  https://github.com/15703396763/Data-Visualizin...
# 2  https://github.com/460Game/King-Slayer/Avery-W...
# 3     https://github.com/460Game/King-Slayer/ryry888
# 4  https://github.com/8tanmoy/parallel_programmin...
#
#                                             repo_url            user  \
# 0  https://github.com/0205Rahul/Breast-Cancer-pre...       Gupta9934
# 1  https://github.com/15703396763/Data-Visualizin...     15703396763
# ...
