# %% [markdown]
# ## Efficiently crawl data from GitHub's GraphQL API
#
# What the current data discovery pipeline do:
#
# 1. crawl a target keywords (uw-madison) with search API
# 1. return these selected data:
#     - repo's name
#     - repo's description
#     - repo's owner (login account)
#     - repo's url
#     - repo's created at timestamp
#     - repo's last push to default branch timestamp
#     - repo's total no. of stars as of now
#     - repo's total commit to default branch as of now
#     - repo's readme
#
# Note to self:
#
# - Utilize GraphQL for Efficiency: GraphQL allows you to request exactly the data you need, reducing unnecessary data transfer.
# - Public Schema for Data Structure: This [public GH GraphQL schema](https://docs.github.com/en/graphql/overview/public-schema) is quite comprehensive.
# - Implement Graceful Retry for Rate Limits: Since GitHub's GraphQL API enforces rate limits, implement a retry mechanism that respects these limits to handle requests gracefully without hitting the rate limit. Refer to the rate limits [documentation]((https://docs.github.com/en/graphql/overview/rate-limits-and-node-limits-for-the-graphql-api)) for guidance.
# - Batch Queries by Year due to Max Results Limit: The maximum number of results you can fetch in one query is 1,000. To work around this, segment your queries by year or another logical division to retrieve all desired data without exceeding this limit.
# - Review and Adjust the Base Query as Necessary: [Existing query](ospo_stats/query.py) may need some changes, especially for handling data updates efficiently. Given the brief runtime of 3 minutes for the entire crawl, the current setup seems fine.

# %%
import logging
import pandas as pd
import altair as alt

from ospo_stats.parser import load
from ospo_stats.gh import discover_repos
logging.basicConfig(level=logging.INFO)

# %%
# Around 3 minutes crawl time from 2010 to 2024
# Run once
# discover_repos("uw-madison", 2010, 2024, overwrite=True, output_dir="data/discovery")

# %% [markdown]
# ## Visualizations
#
# - Cumulative repo by year
# - Cumulative stars by year? (Not implemented yet)
# - Cumulative commits by year? (Not implemented yet)

# %% [markdown]
# ### Calculate cumulative metrics by year

# %%
df = load("data/discovery")
df['year'] = pd.to_datetime(df['created_at']).dt.year

cumulative_repos = df.groupby('year').name.nunique().cumsum()
plot_df = cumulative_repos.reset_index(name='n')

plot_df.head(5)
# Out:
# INFO:root:data/discovery/repos_2011.json
# INFO:root:https://github.com/aaronb/xv6 had no README file
# INFO:root:https://github.com/khazelton/math801f11 had no README file
# INFO:root:data/discovery/repos_2012.json
# INFO:root:https://github.com/jklukas/uwthesis had no README file
# INFO:root:https://github.com/bploeckelman/cs559-project1 had no README file
# INFO:root:https://github.com/bploeckelman/cs559-project3 used a lowercase README file
# INFO:root:https://github.com/UWMadisonUcomm/uwmadison_events-wp had no README file
# INFO:root:https://github.com/nmillin/uw_madison_omega had no README file
# INFO:root:https://github.com/bploeckelman/cs559-project2 had no README file
# INFO:root:https://github.com/schnottus/679_P2 had no README file
# INFO:root:https://github.com/listrophy/programming-happiness had no README file
# INFO:root:https://github.com/kah2011/isthmuswebsite had no README file
# INFO:root:https://github.com/adammaus/CS761-Project had no README file
# INFO:root:https://github.com/mrkline/painter had no README file
# INFO:root:data/discovery/repos_2013.json
# INFO:root:https://github.com/haiyangzhu/Homework had no README file
# INFO:root:https://github.com/katamaritaco/hortonHacksMIT had no README file
# INFO:root:https://github.com/troyhaskin/Dissertation had no README file
# INFO:root:https://github.com/bploeckelman/cs537-project3 had no README file
# INFO:root:https://github.com/bploeckelman/cs537-project5 had no README file
# INFO:root:https://github.com/bploeckelman/cs537-project2 had no README file
# INFO:root:https://github.com/ross-nordstrom/ross-nordstrom.github.io had no README file
# INFO:root:https://github.com/JoshSerbus09/pcap_parser had no README file
# INFO:root:https://github.com/bploeckelman/KinectTestbed had no README file
# INFO:root:data/discovery/repos_2014.json
# INFO:root:https://github.com/markcoatsworth/CS537 had no README file
# INFO:root:https://github.com/jmmccallum/lab2_575_mccallum had no README file
# INFO:root:https://github.com/MariahAndromeda/REUweb had no README file
# INFO:root:https://github.com/crawles/CS760-machine-learning had no README file
# INFO:root:https://github.com/RPGGameTBD/demo_app had no README file
# INFO:root:https://github.com/KevinSJ/CS367_UW-Madison_Spring2014 had no README file
# INFO:root:https://github.com/damouse/cs407_UWMadisonInstagram had no README file
# INFO:root:https://github.com/AlbertoTrindade/picktag had no README file
# INFO:root:https://github.com/azvanderpas/WisconsinAndroids had no README file
# INFO:root:https://github.com/panwaria/LearningFragments had no README file
# INFO:root:https://github.com/panwaria/Board had no README file
# INFO:root:https://github.com/panwaria/PlayMusicService had no README file
# INFO:root:data/discovery/repos_2015.json
# INFO:root:https://github.com/elephantNic/CS407-Quiz1 had no README file
# INFO:root:https://github.com/eotles/BMI776 had no README file
# INFO:root:https://github.com/felipegb94/MadisonEventFeed had no README file
# INFO:root:https://github.com/abzaloid/stat-327 had no README file
# INFO:root:https://github.com/kumar-physics/bmrb had no README file
# INFO:root:https://github.com/wp-plugins/uw-madison-events-calendar had no README file
# INFO:root:https://github.com/kbroman/latex_letter_template had no README file
# INFO:root:https://github.com/andrewshell/insite-entrepreneurship-guide had no README file
# INFO:root:https://github.com/Jynx/UW_Madison_ComputerGraphics_GrTown had no README file
# INFO:root:https://github.com/Jynx/UW_Madison_ComputerGraphics_Train_Project had no README file
# INFO:root:https://github.com/wjhdev/vis used a lowercase README file
# INFO:root:https://github.com/SteveXiSong/UW-Madison-ECE757-S15-MulticastSnooping had no README file
# INFO:root:https://github.com/kbroman/Talk_Showcase2015 had no README file
# INFO:root:https://github.com/jepayne1138/CS407-Lab5 had no README file
# INFO:root:https://github.com/ahclipse/Peoplr had no README file
# INFO:root:https://github.com/jepayne1138/CS407-Homework2-CalendarApp had no README file
# INFO:root:https://github.com/Enlight-UW/EnlightFountainControlLibrary had no README file
# INFO:root:https://github.com/kbroman/Talk_BMI2015 had no README file
# INFO:root:https://github.com/alihitawala/Research_Project_Data_Science had no README file
# INFO:root:https://github.com/tastank/cs564-project had no README file
# INFO:root:https://github.com/sdhar1/CS407 had no README file
# INFO:root:https://github.com/cbscientist/me_analysis had no README file
# INFO:root:data/discovery/repos_2016.json
# INFO:root:https://github.com/palumboeli/CS536 had no README file
# INFO:root:https://github.com/jkoritzinsky/xv6-MLFQ had no README file
# INFO:root:https://github.com/dwortmann/CS368 had no README file
# INFO:root:https://github.com/rroloff/school-projects had no README file
# INFO:root:https://github.com/dcgemperline/withesis had no README file
# INFO:root:https://github.com/sdcalmes/407-hw1-quiz had no README file
# INFO:root:https://github.com/delta-triangle/Triangle had no README file
# INFO:root:https://github.com/agrode9/TEDx had no README file
# INFO:root:https://github.com/ivanpereda95/gitsession had no README file
# INFO:root:https://github.com/jw-mcgrath/overlap_align had no README file
# INFO:root:https://github.com/cbreeden/Math222-S16 had no README file
# INFO:root:https://github.com/YujiaBao/MA522-Lecture-Note had no README file
# INFO:root:https://github.com/zchen1018/Stat628DS had no README file
# INFO:root:https://github.com/WilliamsPaleoLab/Farley_Optimizing_Computing_SDMs had no README file
# INFO:root:https://github.com/NateMoeller/WisconsinEngineer had no README file
# INFO:root:https://github.com/marvynthewall/running-car had no README file
# INFO:root:data/discovery/repos_2017.json
# INFO:root:https://github.com/kreloff-01/kreloff-01.github.io had no README file
# INFO:root:https://github.com/barghouthi/704examples had no README file
# INFO:root:https://github.com/EvenGu/CS537 had no README file
# INFO:root:https://github.com/zwang759/programOne had no README file
# INFO:root:https://github.com/kbroman/Teaching_UWStatGen2017 had no README file
# INFO:root:https://github.com/bkbuchs/GEOG378 had no README file
# INFO:root:https://github.com/RuiteGuo/CS354-dynamic-memory-allocator had no README file
# INFO:root:https://github.com/zaherkarp/regression had no README file
# INFO:root:https://github.com/mfe5003/wi-thesis-bootstrap had no README file
# INFO:root:https://github.com/mannnnnn/Protagonist-GDD had no README file
# INFO:root:https://github.com/bg43179/CS540 had no README file
# INFO:root:https://github.com/myersfinley/rateCalculator had no README file
# INFO:root:https://github.com/RunFranks525/PitchesAndNotesWebApplication had no README file
# INFO:root:https://github.com/bg43179/CS367 had no README file
# INFO:root:https://github.com/bpercy11/CS-536-Compilers had no README file
# INFO:root:https://github.com/TheaWhitman/Soil_Micro_523 had no README file
# INFO:root:https://github.com/shyamal-anadkat/ECE315-AutonomousBot had no README file
# INFO:root:data/discovery/repos_2018.json
# INFO:root:https://github.com/mikedecr/political-numbers-s19 used a lowercase README file
# INFO:root:https://github.com/ttuowang/stats-771-computational-statistics had no README file
# INFO:root:https://github.com/mikedecr/math-camp-2018 had no README file
# INFO:root:https://github.com/agonzaloii/GEOG575_FINALPROJECT had no README file
# INFO:root:https://github.com/kbroman/PBPG957_Sp2018 had no README file
# INFO:root:https://github.com/rrossmiller/DrinkMixer had no README file
# INFO:root:https://github.com/gauthamsunjay/cs537 had no README file
# INFO:root:https://github.com/elbrandt/CS524Project had no README file
# INFO:root:https://github.com/kingmanzhang/CS537-OS-xv6 had no README file
# INFO:root:https://github.com/blemberger/spinsys had no README file
# INFO:root:https://github.com/lramirez5/SegwayProject had no README file
# INFO:root:https://github.com/agonzaloii/GEOG-575 had no README file
# INFO:root:https://github.com/auddya/compPhysLab had no README file
# INFO:root:https://github.com/Heeirun/DiningHallScraper had no README file
# INFO:root:https://github.com/takeshi19/MatrixWorkCpp had no README file
# INFO:root:https://github.com/rsmith52/CS537-Make-Command had no README file
# INFO:root:https://github.com/bumbletai/planets had no README file
# INFO:root:https://github.com/kbroman/Talk_qBio2018 had no README file
# INFO:root:https://github.com/teddpop/tedmart.github.io had no README file
# INFO:root:https://github.com/jkwik/MinorFinder had no README file
# INFO:root:https://github.com/JurijsNazarovs/cs540_F2017 had no README file
# INFO:root:https://github.com/JurijsNazarovs/cs760-S2018 had no README file
# INFO:root:data/discovery/repos_2019.json
# INFO:root:https://github.com/Mattc1221/cs354 had no README file
# INFO:root:https://github.com/cmcsorley/my_website had no README file
# INFO:root:https://github.com/zwang759/program2 had no README file
# INFO:root:https://github.com/XinJiangCN/CS577 had no README file
# INFO:root:https://github.com/zwang759/program0 had no README file
# INFO:root:https://github.com/ChenyunLyu/University-Projects had no README file
# INFO:root:https://github.com/r0b3rt24/entity_matching had no README file
# INFO:root:https://github.com/SomeCallMeTom/UW400-program6 had no README file
# INFO:root:https://github.com/mcraney2/HeapAllocator had no README file
# INFO:root:https://github.com/leschultz/cs760 had no README file
# INFO:root:https://github.com/SomeCallMeTom/UW400-program7 had no README file
# INFO:root:https://github.com/Enya0128/gitExample had no README file
# INFO:root:https://github.com/A-Yifeng/UW-Madison-apartments had no README file
# INFO:root:https://github.com/zhuaa/CS744_UW-Madison had no README file
# INFO:root:https://github.com/zhuaa/CS736_UW-Madison had no README file
# INFO:root:https://github.com/pedrohgoulart/UW-Madison-Class-Projects had no README file
# INFO:root:https://github.com/zhuaa/CS564_UW-Madison had no README file
# INFO:root:https://github.com/vinaynpatil/computer-vision had no README file
# INFO:root:https://github.com/jasonjan2003/ME759hws had no README file
# INFO:root:https://github.com/artorhem/impressions had no README file
# INFO:root:https://github.com/mmstewart/CS540 had no README file
# INFO:root:https://github.com/krusejake/560-Labs had no README file
# INFO:root:https://github.com/EarthCubeGeochron/sparrow-uw-cosmo had no README file
# INFO:root:https://github.com/gtbai/CS839-Data-Science had no README file
# INFO:root:https://github.com/apurbaa7/Discussion-Section-1 had no README file
# INFO:root:https://github.com/cjdunteman/back-propagation-neural-network had no README file
# INFO:root:https://github.com/vinaynpatil/database-management had no README file
# INFO:root:https://github.com/griff16/UW-Madison-Spring-2019-CS540-AI had no README file
# INFO:root:https://github.com/joelm67/Stats_R had no README file
# INFO:root:https://github.com/vinaynpatil/Image-Analysis had no README file
# INFO:root:https://github.com/vladsliusar/spatial-analysis had no README file
# INFO:root:https://github.com/sophbohr22/HerdingMiniGame had no README file
# INFO:root:https://github.com/auddya/FEBiomech603 had no README file
# INFO:root:https://github.com/dlenington/WUD-Music-Newsletter had no README file
# INFO:root:https://github.com/YunyiShen/UW-Course-Projects had no README file
# INFO:root:https://github.com/Matt-Stout/Photography-Website had no README file
# INFO:root:https://github.com/dlshle/JSCourseHelper had no README file
# INFO:root:https://github.com/cascam07/HAPPE-CHTC had no README file
# INFO:root:https://github.com/jrcicardo/Mod03Project had no README file
# INFO:root:https://github.com/jakmus598/ProgrammingII had no README file
# INFO:root:https://github.com/rholson1/django-header-auth had no README file
# INFO:root:data/discovery/repos_2020.json
# INFO:root:https://github.com/UWMadison-computingtools-master/general-info used a lowercase README file
# INFO:root:https://github.com/roumenguha/ECE-524 had no README file
# INFO:root:https://github.com/vinaynpatil/OS_537_Assignments had no README file
# INFO:root:https://github.com/gowtham1234/StorageunitOrganizer had no README file
# INFO:root:https://github.com/jacoparker/CS536 had no README file
# INFO:root:https://github.com/why2000/cs354-p4 had no README file
# INFO:root:https://github.com/LynetteGao/PastJavaProjects had no README file
# INFO:root:https://github.com/dannyedgel/coursework had no README file
# INFO:root:https://github.com/why2000/cs354-p3 had no README file
# INFO:root:https://github.com/mdespe/UW-Covid-API had no README file
# INFO:root:https://github.com/domen111/Computer-Vision-Project had no README file
# INFO:root:https://github.com/alexyavni/CS577 had no README file
# INFO:root:https://github.com/ZolotoiMozg/CS577 had no README file
# INFO:root:https://github.com/chris-chu-7/ece454 had no README file
# INFO:root:https://github.com/why2000/cs354-p6 had no README file
# INFO:root:https://github.com/alexyavni/CS559 had no README file
# INFO:root:https://github.com/ZolotoiMozg/CS367 had no README file
# INFO:root:https://github.com/devinbresser/cs300-uwmadison had no README file
# INFO:root:https://github.com/roumenguha/ECE-532 had no README file
# INFO:root:https://github.com/klmui/UW-Madison-Course-Scheduler had no README file
# INFO:root:https://github.com/jamestautges/742-Homework had no README file
# INFO:root:https://github.com/diwanshu97/Tournament-Scheduler had no README file
# INFO:root:https://github.com/smingari/353_Design_Project had no README file
# INFO:root:https://github.com/alexyavni/CS639 had no README file
# INFO:root:https://github.com/ECMaccoux/CS407-HelloWorld had no README file
# INFO:root:https://github.com/alecyuverymuch/GameTheoryOptimization2017 had no README file
# INFO:root:https://github.com/alexyavni/CS354 had no README file
# INFO:root:https://github.com/ZolotoiMozg/CS536 had no README file
# INFO:root:https://github.com/roumenguha/CS-540 had no README file
# INFO:root:https://github.com/vinaynpatil/PL_538_Assignments had no README file
# INFO:root:https://github.com/lasrubieras/Carpentries_2020_planets had no README file
# INFO:root:https://github.com/shengqin/planets had no README file
# INFO:root:https://github.com/shauryashekhar/CS540-Artificial-Intelligence had no README file
# INFO:root:https://github.com/JayTaves/simEngine3D used a lowercase README file
# INFO:root:https://github.com/ryanbrahim/Dijkstra-s-Shortest-Path had no README file
# INFO:root:https://github.com/crsl4/fast-stats used a lowercase README file
# INFO:root:https://github.com/ychuang6/non-text-feature-analysis had no README file
# INFO:root:https://github.com/msoaresfurtado/UWM_OC_Survey had no README file
# INFO:root:https://github.com/bryanluu/CS425 had no README file
# INFO:root:https://github.com/GrubeG/Geog575LeafletLab1 had no README file
# INFO:root:https://github.com/uwmadisonieee/IEEE-How-To- had no README file
# INFO:root:https://github.com/rawahars/CS744-Distributed-Data-Parallel had no README file
# INFO:root:https://github.com/rawahars/Producer-Consumer-Problem had no README file
# INFO:root:https://github.com/Mattc1221/CS540 had no README file
# INFO:root:https://github.com/dlenington/Pow-App-Functions had no README file
# INFO:root:https://github.com/HaotianShi/CS532 had no README file
# INFO:root:https://github.com/samschiedermayer/cheese-no-consequences had no README file
# INFO:root:https://github.com/birdman550/Course_Nanophotonics_ECE_747 used a lowercase README file
# INFO:root:data/discovery/repos_2021.json
# INFO:root:https://github.com/Madison-Esports-Club/UWVerifierBot had no README file
# INFO:root:https://github.com/manaziraman/CS-407 had no README file
# INFO:root:https://github.com/ttomrp/CS400 had no README file
# INFO:root:https://github.com/olijarm/PS811 had no README file
# INFO:root:https://github.com/jth1011/CS760 had no README file
# INFO:root:https://github.com/jyl6198/cs320 had no README file
# INFO:root:https://github.com/eauwmadison/old.eauw.org had no README file
# INFO:root:https://github.com/cabolz/STAT479-Project had no README file
# INFO:root:https://github.com/cabolz/STAT433-Project had no README file
# INFO:root:https://github.com/JiaxinLi-lipluszn/CS407_Assignments had no README file
# INFO:root:https://github.com/c5h11oh/Database-Buffer-Manager had no README file
# INFO:root:https://github.com/suuranus/FROG_project had no README file
# INFO:root:https://github.com/jth1011/ECE533 had no README file
# INFO:root:https://github.com/digesmartin/CS536 had no README file
# INFO:root:https://github.com/UWHustle/uwhustle.github.io had no README file
# INFO:root:https://github.com/nicholasunderwood/CS-300 had no README file
# INFO:root:https://github.com/sakethsridhara/CS760Project had no README file
# INFO:root:https://github.com/krisrs1128/chtc_crash_course had no README file
# INFO:root:https://github.com/sarah-jbass/Coursework had no README file
# INFO:root:https://github.com/psinha25/cs537-p6 had no README file
# INFO:root:https://github.com/esolache/ece439-final-project had no README file
# INFO:root:https://github.com/thananunmick/bingo had no README file
# INFO:root:https://github.com/GrubeG/Geog576_FinalProject had no README file
# INFO:root:https://github.com/NicholasZoretic/nickGymData had no README file
# INFO:root:https://github.com/tomreitz/cs766-computer-vision-project had no README file
# INFO:root:https://github.com/devanshgoenka97/cs760 had no README file
# INFO:root:https://github.com/ayuj6/CS540-AI had no README file
# INFO:root:https://github.com/teddpop/TheLiveWell-master had no README file
# INFO:root:https://github.com/BressettJ21/GitHub-Language-Prediction had no README file
# INFO:root:https://github.com/esolache/TBR had no README file
# INFO:root:data/discovery/repos_2022.json
# INFO:root:https://github.com/krisrs1128/stat479_s22 had no README file
# INFO:root:https://github.com/grandevelia/deep_learning_cv had no README file
# INFO:root:https://github.com/ammcavoy/CS300 had no README file
# INFO:root:https://github.com/ammcavoy/CS400 had no README file
# INFO:root:https://github.com/ammcavoy/ECE552 had no README file
# INFO:root:https://github.com/timetzw/MA714_Fall2022_UWM had no README file
# INFO:root:https://github.com/kweel/2020-Tokyo-Olympics had no README file
# INFO:root:https://github.com/quandapro/uw-madison had no README file
# INFO:root:https://github.com/demojustine/econ-770-learning had no README file
# INFO:root:https://github.com/armanramiz/QuadCopter-Verilog had no README file
# INFO:root:https://github.com/Nolftop/btn563 had no README file
# INFO:root:https://github.com/madhuNij/Artificial-Intelligence_CS540 had no README file
# INFO:root:https://github.com/RoshanDaniel1208/UW-MADISON-PROJECT had no README file
# INFO:root:https://github.com/prashikpatil221/Convert-UW-Madison had no README file
# INFO:root:https://github.com/p3p31v/UW-Madison-GI had no README file
# INFO:root:https://github.com/janwodnicki/recwell-usage had no README file
# INFO:root:https://github.com/bioyoshoo/UWMGI had no README file
# INFO:root:https://github.com/AkBo24/CS220 had no README file
# INFO:root:https://github.com/ammcavoy/CS537 had no README file
# INFO:root:https://github.com/ukth/UW-Madison_CS300 had no README file
# INFO:root:https://github.com/finnkuusisto/FinnKuusistoCSPage had no README file
# INFO:root:https://github.com/MadisonCSAlumni/website had no README file
# INFO:root:https://github.com/filipmu/madison-gi-tract had no README file
# INFO:root:https://github.com/adubov1/cs400 had no README file
# INFO:root:https://github.com/gjmbur/SOC360fa22 had no README file
# INFO:root:https://github.com/TURX/BadgerMap had no README file
# INFO:root:https://github.com/HarshitKmr10/UW-Madison-GI-Tract-Image-Segmentation had no README file
# INFO:root:https://github.com/sjpark62/UW-Madison.Spring2020-CS559 had no README file
# INFO:root:https://github.com/juhjoo/UW-Madison-GI-Tract-Image-Segmentation had no README file
# INFO:root:https://github.com/LepingLi0810/UW-Madison-CS537-Study-Notes had no README file
# INFO:root:https://github.com/derpysquid1121/UW-Madison-themed-shell-in-C had no README file
# INFO:root:https://github.com/karatach1998/uw-madison-gi-tract-image-segmentation had no README file
# INFO:root:https://github.com/wonjin0403/kaggle_UW-Madison-GI-Tract-Image-Segmentation had no README file
# INFO:root:https://github.com/pri1311/UWM-GI-Tract-Image-Segmentation had no README file
# INFO:root:https://github.com/TylerLDolan/CS400-p3-Hashtable had no README file
# INFO:root:https://github.com/TURX/cs537-distributed-ufs-extra-test had no README file
# INFO:root:https://github.com/tr0nand/769-NLP-Project had no README file
# INFO:root:https://github.com/Patricia-Mcmillin/PMcmillin_REU had no README file
# INFO:root:https://github.com/cms0008/lis646 had no README file
# INFO:root:https://github.com/rhysandmh/CS354-MachineOrganization had no README file
# INFO:root:https://github.com/jtabraham123/2020-Badger-Football-Manager had no README file
# INFO:root:https://github.com/kalmizyed/CS400_Project1_Show_Searcher had no README file
# INFO:root:https://github.com/kbroman/Teaching_UWStatGen2022 had no README file
# INFO:root:https://github.com/kalmizyed/CS400_Project3_Star_Wars_Social_Network had no README file
# INFO:root:https://github.com/kalmizyed/CS400_Project2_Task_Scheduler had no README file
# INFO:root:https://github.com/Robertleoj/GI_Tract_Segmentation had no README file
# INFO:root:https://github.com/kalmizyed/CS400_Project3_Dijkstra had no README file
# INFO:root:https://github.com/cms0008/ischoolsocialclub had no README file
# INFO:root:https://github.com/tingtingweng/photocatalyst_ml had no README file
# INFO:root:https://github.com/aliciajwood/d3-lab had no README file
# INFO:root:https://github.com/natbyoung/leaflet-lab had no README file
# INFO:root:https://github.com/CWacker259/Production-Optimization-using-Integer-Programming-Methods had no README file
# INFO:root:https://github.com/saisoma123/Folder-Explorer had no README file
# INFO:root:https://github.com/saisoma123/Assignment-Planner had no README file
# INFO:root:https://github.com/ztcollins/CoursePathCalculator had no README file
# INFO:root:https://github.com/Rim-chan/GI-Tract-Image-Segmentation had no README file
# INFO:root:https://github.com/jsangha16/SubredditWebScraper had no README file
# INFO:root:data/discovery/repos_2023.json
# INFO:root:https://github.com/cluangrath4/WiscEvents had no README file
# INFO:root:https://github.com/BenjaminHayum/Data-Modeling-II had no README file
# INFO:root:https://github.com/BenjaminHayum/Intro-to-Artificial-Intelligence had no README file
# INFO:root:https://github.com/BenjaminHayum/Deep-Learning-and-Generative-Models had no README file
# INFO:root:https://github.com/BenjaminHayum/Intro-to-Optimization had no README file
# INFO:root:https://github.com/paipeline/Java_projects had no README file
# INFO:root:https://github.com/dawn-cmd/Uw-Madison had no README file
# INFO:root:https://github.com/r-universe/uw-madison-dsi had no README file
# INFO:root:https://github.com/zinnia11/CS-300 had no README file
# INFO:root:https://github.com/kpister/uproject had no README file
# INFO:root:https://github.com/kevinsinghgill/CS760 had no README file
# INFO:root:https://github.com/zinnia11/CS-400 had no README file
# INFO:root:https://github.com/madhuNij/Machine-Learning_CS760 had no README file
# INFO:root:https://github.com/ShixiaoLiang320/CS760 had no README file
# INFO:root:https://github.com/jcnf0/courses had no README file
# INFO:root:https://github.com/AnteT/cs760 had no README file
# INFO:root:https://github.com/tapanr25/CS-760-Machine-Learning had no README file
# INFO:root:https://github.com/zinnia11/CS-577 had no README file
# INFO:root:https://github.com/JeremyKedziora/UW-Madison-PS272 had no README file
# INFO:root:https://github.com/JeremyKedziora/UW-Madison-PS270 had no README file
# INFO:root:https://github.com/rowan-tich/UW-Madison-Campus-Map had no README file
# INFO:root:https://github.com/Elliethieu/Machine-learning-projects had no README file
# INFO:root:https://github.com/zinnia11/CS-642 had no README file
# INFO:root:https://github.com/wgraysonp/CS760 had no README file
# INFO:root:https://github.com/zinnia11/CS-354 had no README file
# INFO:root:https://github.com/zinnia11/STAT324 had no README file
# INFO:root:https://github.com/wallenben/CS536 used a lowercase README file
# INFO:root:https://github.com/zinnia11/ECE532 had no README file
# INFO:root:https://github.com/spitz21/CS400-Final-Project had no README file
# INFO:root:https://github.com/yosunlu/UW-Madison-CS220-Data-Programming had no README file
# INFO:root:https://github.com/SocialInteractionLab/socialinteractionlab.github.io had no README file
# INFO:root:https://github.com/ghetchler/JavaCourseWork_CS400 had no README file
# INFO:root:https://github.com/lneuendorf/CS760-MachineLearning had no README file
# INFO:root:https://github.com/salmanmunaf/cs744 had no README file
# INFO:root:https://github.com/muhammad-musa-ml/CS760 had no README file
# INFO:root:https://github.com/unawks02/JavaAndCExperience had no README file
# INFO:root:https://github.com/salmanmunaf/cs552 had no README file
# INFO:root:https://github.com/salmanmunaf/cs537 had no README file
# INFO:root:https://github.com/hobbitlab/uw3D had no README file
# INFO:root:https://github.com/unawks02/SLiM had no README file
# INFO:root:https://github.com/ajlarson24/GEOG778-Project had no README file
# INFO:root:https://github.com/hstrohbusch/UW-CS-Work had no README file
# INFO:root:https://github.com/vinayswamik/Qiskit-Fall-Fest-2023 had no README file
# INFO:root:https://github.com/devinbresser/ece533-uwmadison had no README file
# INFO:root:https://github.com/salmanmunaf/cs564 had no README file
# INFO:root:https://github.com/desiredbean/BadgerNotify had no README file
# INFO:root:https://github.com/klicker08/FoodParser had no README file
# INFO:root:https://github.com/spitz21/Iwine had no README file
# INFO:root:https://github.com/DavidSalazar123/WisconsinMap had no README file
# INFO:root:https://github.com/kevinzhao79/HAC had no README file
# INFO:root:https://github.com/dremilybick/Pest-population-teaching-model had no README file
# INFO:root:https://github.com/masonrware/cosi-354-repo had no README file
# INFO:root:https://github.com/KssNikhil2002/CS354---Machine-Organization-and-Programming-Projects- had no README file
# INFO:root:https://github.com/b1urberry/UWBuildingGuideModel had no README file
# INFO:root:https://github.com/AryanSV5/Madison_Travel_Application had no README file
# INFO:root:https://github.com/hannaheow/June2023REUIntroR had no README file
# INFO:root:data/discovery/repos_2024.json
# INFO:root:https://github.com/msonnenburg/STAT_436 had no README file
# INFO:root:https://github.com/aliciajwood/geog-778-final-project had no README file
# INFO:root:https://github.com/srathod16/UW-Madison_egen_emissions had no README file
# INFO:root:https://github.com/Yuqing-Janet-Zhao/econ_580_assignment_2 had no README file
# INFO:root:https://github.com/hyunjongkimmath/gross_zagier_reading_seminar_UW_Madison_Spring_2024 had no README file
# INFO:root:https://github.com/zheliu17/TBE_template had no README file
# INFO:root:https://github.com/kevinzhao79/cs564-sp24 had no README file
#    year    n
# 0  2011    2
# 1  2012   25
# 2  2013   47
# 3  2014   84
# 4  2015  139

# %% [markdown]
# ### Plot cumulative metrics by year

# %%
plot = alt.Chart(plot_df).mark_line(point=True).encode(
    x='year:O', 
    y='n:Q',
).properties(
    title="Yearly Growth of UW–Madison's Open-Source Repositories on GitHub",
    width=600,
    height=400
)

plot
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Somewhat interesting statistics
#
# - top-10 stared repo
# - top-10 commited repo

# %%
df.sort_values('stars', ascending=False).head(10)
# Out:
#                                         name  \
# 513               stat453-deep-learning-ss20
# 694               stat453-deep-learning-ss21
# 514            stat451-machine-learning-fs20
# 830                            Kaggle-UWMGIT
# 375                       prepare-tax-return
# 264                            madgrades.com
# 49                             JuliaWorkshop
# 370      UW-Madison-CS540-Introduction-to-AI
# 371  uw-madison-datacience-club-talk-oct2019
# 268                             Intro-to-MRI
#
#                                            description       owner  \
# 513  STAT 453: Intro to Deep Learning @ UW-Madison ...       rasbt
# 694  STAT 453: Intro to Deep Learning @ UW-Madison ...       rasbt
# 514  STAT 451: Intro to Machine Learning @ UW-Madis...       rasbt
# 830  code for kaggle: UW-Madison GI Tract Image Seg...   CarnoZhao
# 375                              UW-Madison CS 硕士生报税经历       mzj14
# 264  Frontend for visualizing UW Madison course gra...   Madgrades
# 49   Materials for a workshop on Julia programming ...     dmbates
# 370  UW-Madison CS540: Introduction to Artificial I...  learlinian
# 371  Slides and code for the talk at UW-Madison's D...       rasbt
# 268  This is Jupyter notebook/python code developed...  kmjohnson3
#
#                                                    url            created_at  \
# 513  https://github.com/rasbt/stat453-deep-learning...  2020-01-20T23:20:22Z
# 694  https://github.com/rasbt/stat453-deep-learning...  2021-01-28T03:46:42Z
# 514  https://github.com/rasbt/stat451-machine-learn...  2020-08-06T23:42:45Z
# 830         https://github.com/CarnoZhao/Kaggle-UWMGIT  2022-05-08T07:39:51Z
# 375        https://github.com/mzj14/prepare-tax-return  2019-03-19T00:38:09Z
# 264         https://github.com/Madgrades/madgrades.com  2018-02-27T08:07:01Z
# 49            https://github.com/dmbates/JuliaWorkshop  2014-06-17T14:46:20Z
# 370  https://github.com/learlinian/UW-Madison-CS540...  2019-02-10T00:55:59Z
# 371  https://github.com/rasbt/uw-madison-datacience...  2019-10-11T02:44:06Z
# 268         https://github.com/kmjohnson3/Intro-to-MRI  2018-11-05T16:05:57Z
#
#                 pushed_at  stars  issues  commits  \
# 513  2020-05-01T22:34:04Z    545       2       84
# 694  2022-02-03T22:57:35Z    398       4       44
# 514  2020-12-03T05:43:06Z    366       1       32
# 830  2022-10-18T17:34:22Z     87       7      437
# 375  2019-03-24T15:31:33Z     49       0        8
# 264  2024-01-10T09:00:30Z     47      10      121
# 49   2019-06-10T17:29:01Z     31       0       50
# 370  2021-10-09T08:51:56Z     24       0       48
# 371  2019-10-11T02:49:31Z     20       0        2
# 268  2024-03-04T23:23:29Z     19       0       41
#
#                                                 readme  year
# 513  # STAT 453: Introduction to Deep Learning and ...  2020
# 694  # stat453-deep-learning-ss21\nSTAT 453: Intro ...  2021
# 514  [![Binder](https://mybinder.org/badge_logo.svg...  2020
# 830  ### Introduction\n\nHello!\n\nBelow you can fi...  2022
# 375  # prepare-tax-return\n作为UW-Madison CS 硕士生的个人报税...  2019
# 264  # madgrades.com [![Build and deploy to prod](h...  2018
# 49   JuliaWorkshop\n=============\n\nMaterials for ...  2014
# 370  # UW-Madison CS540: Introduction to Artificial...  2019
# 371  # uw-madison-datacience-club-talk-oct2019\nSli...  2019
# 268  # Intro-to-MRI\nThis is Jupyter notebook/pytho...  2018

# %% [markdown]
# - Most popular repo are course materials
# - Need some way to categorize repo, e.g., LLM with readme / descriptions

# %% [markdown]
# ### Top-10 most committed repos

# %%
df.sort_values('commits', ascending=False).head(10)
# Out:
#                           name  \
# 1234  WisconsinDiamondQubitLab
# 50             2014-08-25-wisc
# 319      2018-15-08-UW-Madison
# 274    2018-06-04-uwmadison-dc
# 279   2018-06-06-uwmadison-swc
# 87        2016-01-14-uwmadison
# 826                   Scavenge
# 86       2015-08-26-uw-madison
# 88        2016-01-11-uwmadison
# 105         uw-madison-wp-2015
#
#                                             description           owner  \
# 1234  Codebase to run the Wisconsin Diamond Qubit La...        GardillA
# 50           Software Carpentry Boot Camp at UW-Madison  UW-Madison-ACI
# 319                                                None       mkamenet3
# 274   Website for June 2018 Data Carpentry workshop ...  UW-Madison-ACI
# 279   Website for June 2018 Software Carpentry works...  UW-Madison-ACI
# 87    http://uw-madison-aci.github.io/2016-01-14-uwm...  UW-Madison-ACI
# 826   Search for food you need at local food pantrie...     Scavenge-UW
# 86                                                 None  UW-Madison-ACI
# 88    http://uw-madison-aci.github.io/2016-01-11-uwm...  UW-Madison-ACI
# 105                                                None   uwmadisoncals
#
#                                                     url            created_at  \
# 1234  https://github.com/GardillA/WisconsinDiamondQu...  2023-07-13T16:58:49Z
# 50    https://github.com/UW-Madison-ACI/2014-08-25-wisc  2014-07-29T02:25:37Z
# 319   https://github.com/mkamenet3/2018-15-08-UW-Mad...  2018-08-15T22:07:58Z
# 274   https://github.com/UW-Madison-ACI/2018-06-04-u...  2018-05-01T17:57:52Z
# 279   https://github.com/UW-Madison-ACI/2018-06-06-u...  2018-05-01T17:58:43Z
# 87    https://github.com/UW-Madison-ACI/2016-01-14-u...  2015-11-24T20:08:35Z
# 826             https://github.com/Scavenge-UW/Scavenge  2021-02-13T00:52:25Z
# 86    https://github.com/UW-Madison-ACI/2015-08-26-u...  2015-07-30T20:10:53Z
# 88    https://github.com/UW-Madison-ACI/2016-01-11-u...  2015-11-24T14:44:21Z
# 105   https://github.com/uwmadisoncals/uw-madison-wp...  2015-05-18T15:27:02Z
#
#                  pushed_at  stars  issues  commits  \
# 1234  2023-07-18T03:42:14Z      0       0     3180
# 50    2014-08-15T18:45:16Z      3       0     1519
# 319   2018-08-15T22:12:57Z      0       0     1315
# 274   2018-08-29T11:48:25Z      0       0     1160
# 279   2018-06-05T21:19:48Z      0       0     1147
# 87    2016-01-15T21:48:46Z      1       0      632
# 826   2021-05-01T04:23:23Z      2      97      620
# 86    2015-08-25T17:28:51Z      0       1      588
# 88    2016-01-14T17:47:12Z      0       0      555
# 105   2019-04-12T16:55:46Z      0      11      555
#
#                                                  readme  year
# 1234  This codebase is based off of the codebase ori...  2023
# 50    Software Carpentry Bootcamps\n================...  2014
# 319   # workshop-template\n\nThis repository is [Sof...  2018
# 274   ## Data Carpentry @ UW Madison\n### June 4-5, ...  2018
# 279   # workshop-template\n\nThis repository is [Sof...  2018
# 87    # workshop-template\n\nThis repository is [Sof...  2015
# 826   # Scavenge\nSearch for food you need at local ...  2021
# 86    # workshop-template\n\nThis repository is [Sof...  2015
# 88    =======\n\nThis repository is the [Data Carpen...  2015
# 105   \nA UW-Madison Wordpress Theme\n===\n\nThis is...  2015

# %%
print(f"we have a total of {len(df)} repos, and on average, they have {df.commits.mean():.1f} commits")
# Out:
# we have a total of 1299 repos, and on average, they have 35.8 commits

# %% [markdown]
# - I looked at a top repo, many commits are coming from bot for CIs. We need filter out those bot's commits.
# - Activeness can be defined as: most commits in the past year. We need historical commit data for it. Estimated crawl time = 1.1 call * 3s * 1299 repos = 72 minutes < 2 hours... not as bad as I thought.

# %% [markdown]
# ## Future plans / discussion

# %% [markdown]
# ## Historical details (Work in progress)
#
# Not going to pull all data for now. Need to discuss what to pull.

# %%
from ospo_stats.gh import get_stargazers, get_commits
from ospo_stats.parser import parse_stargazers, parse_commits

# %% [markdown]
# ### Example of crawling historical star history in a repo

# %%
gs = get_stargazers("ad-freiburg", "qlever")
gs = [parse_stargazers(g) for g in gs]
pd.DataFrame(gs).head(5)
# Out:
# INFO:root:Obtained stargazers: 100 / 252
# INFO:root:Obtained stargazers: 200 / 252
# INFO:root:Obtained stargazers: 252 / 252
#              starred_at              user
# 0  2015-07-16T12:46:16Z  hello009-commits
# 1  2016-01-20T16:37:51Z           titsuki
# 2  2016-07-28T13:05:09Z          Buchhold
# 3  2016-12-22T12:45:22Z         PawelMarc
# 4  2017-01-10T21:48:18Z      diegoesteves

# %% [markdown]
# ### Example of crawling historical commit history in a repo

# %%
cs = get_commits("jasonlo", "funsearch")
cs = [parse_commits(c) for c in cs]
pd.DataFrame(cs).head(5)
# Out:
# INFO:root:Obtained commits: 51 / 51
#            committed_at                                                url  \
# 0  2024-02-22T18:42:10Z  https://github.com/JasonLo/funsearch/commit/97...
# 1  2024-02-22T17:23:06Z  https://github.com/JasonLo/funsearch/commit/02...
# 2  2024-02-22T17:08:18Z  https://github.com/JasonLo/funsearch/commit/52...
# 3  2024-02-22T17:05:22Z  https://github.com/JasonLo/funsearch/commit/31...
# 4  2024-02-22T07:08:17Z  https://github.com/JasonLo/funsearch/commit/71...
#
#    additions  deletions committer_name   committer_email
# 0         66         50       Jason Lo  lcmjlo@gmail.com
# 1         18          0       Jason Lo  lcmjlo@gmail.com
# 2        441        407       Jason Lo  lcmjlo@gmail.com
# 3        155        115       Jason Lo  lcmjlo@gmail.com
# 4        331        289       Jason Lo  lcmjlo@gmail.com

# %% [markdown]
# ### To-dos
#
# - Add community metric (health %)
# - Get accurate historical data of stars and commits instead of using total no. as of now.
# - Get some inspiration from: https://r-universe.dev/search/
# - Clarify what details info are needed for outreach? Exemplary OSS repos?
# - Categorize repo type (e.g., course content, software) by repo's `description` and `readme` with LLM.
