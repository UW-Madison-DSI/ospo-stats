# %% [markdown]
# ## Efficiently crawl data from GitHub's GraphQL API
#
# Note to self:
#
# - Utilize GraphQL for Efficiency: GraphQL allows you to request exactly the data you need, reducing unnecessary data transfer.
# - Public Schema for Data Structure: This [public GH GraphQL schema](https://docs.github.com/en/graphql/overview/public-schema) is quite comprehensive.
# - Implement Graceful Retry for Rate Limits: Since GitHub's GraphQL API enforces rate limits, implement a retry mechanism that respects these limits to handle requests gracefully without hitting the rate limit. Refer to the rate limits [documentation]((https://docs.github.com/en/graphql/overview/rate-limits-and-node-limits-for-the-graphql-api)) for guidance.
# - Batch Queries by Year due to Max Results Limit: The maximum number of results you can fetch in one query is 1,000. To work around this, segment your queries by year or another logical division to retrieve all desired data without exceeding this limit.
# - Review and Adjust the Base Query as Necessary: [Existing query](ospo_stats/query.py) may need some changes, especially for handling data updates efficiently. Given the brief runtime of 3 minutes for the entire crawl, the current setup seems fine.

# %%
from ospo_stats.gh import crawl

# Around 3 minutes run time from 2010 to 2024 , this will store all raw data to `data/` dir
# Run once only
# crawl("uw-madison", 2010, 2024, overwrite=True)

# %% [markdown]
# ## Visualizations
#
# - Cumulative repo by year
# - Cumulative stars by year? This isn't about the stars received each year, but the total stars a repository has now, with repositories categorized based on the year they were created. TODO: Somewhat misleading, may need fix.
# - Cumulative commits by year? Similar to above, it is the total commits a repository has now, grouped by repo creation year. TODO: Somewhat misleading, may need fix.

# %% [markdown]
# ### Calculate cumulative metrics by year

# %%
import pandas as pd
import altair as alt
from ospo_stats.parser import load

df = load("data/")
df['year'] = pd.to_datetime(df['created_at']).dt.year

cumulative_repos = df.groupby('year').name.nunique().cumsum()
plot_df_repo = cumulative_repos.reset_index(name='n')

cumulative_stars = df.groupby('year').stars.sum().cumsum()
plot_df_stars = cumulative_stars.reset_index(name='stars')

cumulative_commits = df.groupby('year').commits.sum().cumsum()
plot_df_commits = cumulative_commits.reset_index(name='commits')

plot_df = plot_df_repo.merge(plot_df_stars, on='year').merge(plot_df_commits, on='year').melt('year', var_name='metric')
plot_df.sample(5)
# Out:
#     year   metric  value
# 1   2012        n     25
# 29  2012  commits   1771
# 13  2024        n   1266
# 4   2015        n    139
# 10  2021        n    823

# %% [markdown]
# ### Plot cumulative metrics by year

# %%
plot = alt.Chart(plot_df).mark_line(point=True).encode(
    x='year:O', 
    y='value:Q',
    color='metric:N',
    column='metric:N'
).properties(
    title='Open-source repositories affiliated with UW–Madison',
    width=600,
    height=400
).resolve_scale(y='independent')

plot
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Somewhat interesting statistics
#
# - top-10 stared repo
# - top-10 commited repo

# %%
df.sort_values('stars', ascending=False).head(10)
# Out:
#                                         name  \
# 513               stat453-deep-learning-ss20
# 694               stat453-deep-learning-ss21
# 514            stat451-machine-learning-fs20
# 830                            Kaggle-UWMGIT
# 375                       prepare-tax-return
# 264                            madgrades.com
# 49                             JuliaWorkshop
# 370      UW-Madison-CS540-Introduction-to-AI
# 371  uw-madison-datacience-club-talk-oct2019
# 295                 command-line-interpreter
#
#                                                    url  \
# 513  https://github.com/rasbt/stat453-deep-learning...
# 694  https://github.com/rasbt/stat453-deep-learning...
# 514  https://github.com/rasbt/stat451-machine-learn...
# 830         https://github.com/CarnoZhao/Kaggle-UWMGIT
# 375        https://github.com/mzj14/prepare-tax-return
# 264         https://github.com/Madgrades/madgrades.com
# 49            https://github.com/dmbates/JuliaWorkshop
# 370  https://github.com/learlinian/UW-Madison-CS540...
# 371  https://github.com/rasbt/uw-madison-datacience...
# 295  https://github.com/amanchadha/command-line-int...
#
#                                            description            created_at  \
# 513  STAT 453: Intro to Deep Learning @ UW-Madison ...  2020-01-20T23:20:22Z
# 694  STAT 453: Intro to Deep Learning @ UW-Madison ...  2021-01-28T03:46:42Z
# 514  STAT 451: Intro to Machine Learning @ UW-Madis...  2020-08-06T23:42:45Z
# 830  code for kaggle: UW-Madison GI Tract Image Seg...  2022-05-08T07:39:51Z
# 375                              UW-Madison CS 硕士生报税经历  2019-03-19T00:38:09Z
# 264  Frontend for visualizing UW Madison course gra...  2018-02-27T08:07:01Z
# 49   Materials for a workshop on Julia programming ...  2014-06-17T14:46:20Z
# 370  UW-Madison CS540: Introduction to Artificial I...  2019-02-10T00:55:59Z
# 371  Slides and code for the talk at UW-Madison's D...  2019-10-11T02:44:06Z
# 295  Unix Shell in C | Support for built-in command...  2018-12-19T06:39:28Z
#
#                 pushed_at  stars  issues  commits  \
# 513  2020-05-01T22:34:04Z    545       2       84
# 694  2022-02-03T22:57:35Z    398       4       44
# 514  2020-12-03T05:43:06Z    366       1       32
# 830  2022-10-18T17:34:22Z     87       7      437
# 375  2019-03-24T15:31:33Z     49       0        8
# 264  2024-01-10T09:00:30Z     47      10      121
# 49   2019-06-10T17:29:01Z     31       0       50
# 370  2021-10-09T08:51:56Z     24       0       48
# 371  2019-10-11T02:49:31Z     20       0        2
# 295  2018-12-31T23:18:56Z     19       0       15
#
#                                                 readme  year
# 513  # STAT 453: Introduction to Deep Learning and ...  2020
# 694  # stat453-deep-learning-ss21\nSTAT 453: Intro ...  2021
# 514  [![Binder](https://mybinder.org/badge_logo.svg...  2020
# 830  ### Introduction\n\nHello!\n\nBelow you can fi...  2022
# 375  # prepare-tax-return\n作为UW-Madison CS 硕士生的个人报税...  2019
# 264  # madgrades.com [![Build and deploy to prod](h...  2018
# 49   JuliaWorkshop\n=============\n\nMaterials for ...  2014
# 370  # UW-Madison CS540: Introduction to Artificial...  2019
# 371  # uw-madison-datacience-club-talk-oct2019\nSli...  2019
# 295  ﻿Command Line Interpreter (Shell)\n===========...  2018

# %%
df.sort_values('commits', ascending=False).head(10)
# Out:
#                           name  \
# 1234  WisconsinDiamondQubitLab
# 50             2014-08-25-wisc
# 318      2018-15-08-UW-Madison
# 274    2018-06-04-uwmadison-dc
# 279   2018-06-06-uwmadison-swc
# 87        2016-01-14-uwmadison
# 826                   Scavenge
# 86       2015-08-26-uw-madison
# 88        2016-01-11-uwmadison
# 105         uw-madison-wp-2015
#
#                                                     url  \
# 1234  https://github.com/GardillA/WisconsinDiamondQu...
# 50    https://github.com/UW-Madison-ACI/2014-08-25-wisc
# 318   https://github.com/mkamenet3/2018-15-08-UW-Mad...
# 274   https://github.com/UW-Madison-ACI/2018-06-04-u...
# 279   https://github.com/UW-Madison-ACI/2018-06-06-u...
# 87    https://github.com/UW-Madison-ACI/2016-01-14-u...
# 826             https://github.com/Scavenge-UW/Scavenge
# 86    https://github.com/UW-Madison-ACI/2015-08-26-u...
# 88    https://github.com/UW-Madison-ACI/2016-01-11-u...
# 105   https://github.com/uwmadisoncals/uw-madison-wp...
#
#                                             description            created_at  \
# 1234  Codebase to run the Wisconsin Diamond Qubit La...  2023-07-13T16:58:49Z
# 50           Software Carpentry Boot Camp at UW-Madison  2014-07-29T02:25:37Z
# 318                                                None  2018-08-15T22:07:58Z
# 274   Website for June 2018 Data Carpentry workshop ...  2018-05-01T17:57:52Z
# 279   Website for June 2018 Software Carpentry works...  2018-05-01T17:58:43Z
# 87    http://uw-madison-aci.github.io/2016-01-14-uwm...  2015-11-24T20:08:35Z
# 826   Search for food you need at local food pantrie...  2021-02-13T00:52:25Z
# 86                                                 None  2015-07-30T20:10:53Z
# 88    http://uw-madison-aci.github.io/2016-01-11-uwm...  2015-11-24T14:44:21Z
# 105                                                None  2015-05-18T15:27:02Z
#
#                  pushed_at  stars  issues  commits  \
# 1234  2023-07-18T03:42:14Z      0       0     3180
# 50    2014-08-15T18:45:16Z      3       0     1519
# 318   2018-08-15T22:12:57Z      0       0     1315
# 274   2018-08-29T11:48:25Z      0       0     1160
# 279   2018-06-05T21:19:48Z      0       0     1147
# 87    2016-01-15T21:48:46Z      1       0      632
# 826   2021-05-01T04:23:23Z      2      97      620
# 86    2015-08-25T17:28:51Z      0       1      588
# 88    2016-01-14T17:47:12Z      0       0      555
# 105   2019-04-12T16:55:46Z      0      11      555
#
#                                                  readme  year
# 1234  This codebase is based off of the codebase ori...  2023
# 50    Software Carpentry Bootcamps\n================...  2014
# 318   # workshop-template\n\nThis repository is [Sof...  2018
# 274   ## Data Carpentry @ UW Madison\n### June 4-5, ...  2018
# 279   # workshop-template\n\nThis repository is [Sof...  2018
# 87    # workshop-template\n\nThis repository is [Sof...  2015
# 826   # Scavenge\nSearch for food you need at local ...  2021
# 86    # workshop-template\n\nThis repository is [Sof...  2015
# 88    =======\n\nThis repository is the [Data Carpen...  2015
# 105   \nA UW-Madison Wordpress Theme\n===\n\nThis is...  2015

# %% [markdown]
# ## Future plans / discussion
#
# 1. Get some inspiration from: https://r-universe.dev/search/
# 2. What info are needed for outreach? Exemplary OSS repos?
# 3. Categorization by repo's `description` and `readme` with LLM.
